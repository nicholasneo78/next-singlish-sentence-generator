# %% [markdown]
# # Phase 4b: Using a Transformer (GPT-2) for natural language generation (NLG)

# %%
from google.colab import drive
from google.colab import files
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# backward compatibility
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '1.15.2'

# %% [markdown]
# ## DECLARING CONSTANTS

# %%
# file paths of the dataset
DATA = ["SgCorpus"]
COLAB_FILEPATH = './drive/My Drive/next-sentence-predictor/finalData/'

# %% [markdown]
# ## DECLARE FINAL FILEPATH

# %%
# DECLARE THE FINAL FILEPATH TO LOAD THE DATA
filename = COLAB_FILEPATH + DATA[0] + '.txt'

# %% [markdown]
# ## Import relevant library for training using GPT-2

# %%
# !pip install gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
# Out:
# Collecting gpt-2-simple
#   Downloading https://files.pythonhosted.org/packages/6f/e4/a90add0c3328eed38a46c3ed137f2363b5d6a07bf13ee5d5d4d1e480b8c3/gpt_2_simple-0.7.1.tar.gz
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (4.41.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (1.18.5)
# Collecting toposort
#   Downloading https://files.pythonhosted.org/packages/e9/8a/321cd8ea5f4a22a06e3ba30ef31ec33bea11a3443eeb1d89807640ee6ed4/toposort-1.5-py2.py3-none-any.whl
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (3.0.4)
# Building wheels for collected packages: gpt-2-simple
#   Building wheel for gpt-2-simple (setup.py) ... done
#   Created wheel for gpt-2-simple: filename=gpt_2_simple-0.7.1-cp36-none-any.whl size=23581 sha256=458b835b554342c4d2a6f6894b3ea9961419acb7f8dcacdde60d8305668ce85a
#   Stored in directory: /root/.cache/pip/wheels/0c/f8/23/b53ce437504597edff76bf9c3b8de08ad716f74f6c6baaa91a
# Successfully built gpt-2-simple
# Installing collected packages: toposort, gpt-2-simple
# Successfully installed gpt-2-simple-0.7.1 toposort-1.5
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
# download the gpt-2 small model
gpt2.download_gpt2(model_name="124M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 341Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 89.3Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 899Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:02, 196Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 287Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 176Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 154Mit/s]

# %% [markdown]
# ## Fine-tuning the GPT-2 model

# %%
# fine-tuning of gpt-2 model
tf.reset_default_graph()
    
sess = gpt2.start_tf_sess()

gpt2.finetune(sess,
              dataset=filename,
              model_name='124M',
              steps=100,
              restore_from='fresh',
              run_name='run1',
              print_every=25,
              sample_every=20,
              save_every=10
              )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
# Loading dataset...
# 100%|██████████| 1/1 [00:24<00:00, 24.08s/it]
# dataset has 5476259 tokens
# Training...
# Saving checkpoint/run1/model-10
# Saving checkpoint/run1/model-20
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# ======== SAMPLE 1 ========
#  i, i cannot fathom being able to write a book about. i think i am just doing my best to try, but my best guess is, that i did not like the ending of the first two chapters. i think that's just the feeling of a disappointment that i did not deserve to finish my story even though it was already done. it still feels good after but i do not think i have fully decided if i want to continue reading. i am sad this is an issue that has not happened in this series i have written thus far... not only that i do not know the outcome at all, but i will not even know my own story that i am going to.
#
# so, it has been more than a week and i have no sleep yet. i am tired of living with the stress of daily tasks. i went home from work and had a great start in my work with this project, i was really glad that i found out in no time. to say i am too lazy is an understatement. i have to stay up during 3-4 hours a day as well as for hours after but for the most part, it is me getting up during the day after. i am not used to that because i have to work so much during the day, especially on weekends and holidays. but i must say, it is nice knowing that there is something to be achieved. i am not sure if it is my own happiness but my own work and the fact i am not working, or if my boss is the one trying to make this project harder is something that I have not had the courage to share in time.
#
# i am really tired of being able to write more and to not waste too much on one thing.
#
# thank you everyone for giving me this opportunity, i sincerely pray to you guys, one day everyone will be able to complete your story without the burden of a single effort that would have prevented you from writing the book. and i will continue to work hard for my story!. to the people who have helped me, thank you. to the people who gave me the opportunity to continue my story without giving up. thank you for giving me the opportunity to continue my own story!.
#
# i finally have a story. but it seems like it is my last book to finish. how do i finish the story?
#
# i am reading your first post and the first sentence is just too long. i cannot finish this one at this point, will not finish this one too soon. but there are some other people you can help and i did not know if i had. but for me, the biggest challenge for me is the writing. i do not know how to read the story of the person or the sentence. but for a story like this, i am pretty desperate. so, with your help, i will go ahead and start writing a story about my life and how i got to where i am, before the end. that will have a major impact on my writing. i am very lucky.
#
# i am a self proclaimed 'energetic, fun & funny teacher'. no matter how many kids do you grow up with, their school life is forever and always will be different and they will always be different as well. so, after i start, i think it is my task to continue to continue to improve my writing. and i realised that writing is so hard, and the hardest thing is not working out to get better. it is not so easy to reach a goal when you do not get motivated by what you do.
#
# i just came home from school, and i did not work out so much. i was at my best with the writing but after reading this blog post, i am tired of me having this feeling and i did not feel that i could not work on something. it does not matter if it is a bad teacher or not.. how it feels is not a problem to me. so, in the beginning, i tried to make sure i was getting on time with my work as it is such a stressful job in school. but after i read your blog post i decided it is not working out for me or for my work. i feel like i can still write.
#
# i am currently studying for a PhD. i am at this point thinking more about what i am doing and how i am doing it than how to solve the problem. i am currently reading your first story and wondering what i am writing about. will it be good? please let us know who has been helping me.
#
# i have been studying for my PhD, and i was wondering, will the next project be different in that?
#
# i am so grateful that you guys helped me write such funny fiction! i am very thankful for all of you for writing funny stories like these with your help.
#
#  i hope i will get to know you guys much faster. i really love to ask you.
#
# i do like to think that it will be a few things that i have learnt the biggest thing
#
# [25 | 105.23] loss=3.62 avg=3.62
# Saving checkpoint/run1/model-30
# Saving checkpoint/run1/model-40
# ======== SAMPLE 1 ========
# ense.p.c.s.r.r.i.e.. the fact that the whole country's population is living and working at home.p.c.w.a.n.d.i.i.o.d.l.d.m.j.g.e. i.c.s.d.w.t.e.j.i.e. the fact that the whole country's population is living and working at home.p.c.s.d.w.t.e.j.i.c.s.d.m.j.g.e. i.d.n.d.c.a.d.l.c.s.d.d.m.j.g.j.g.e.j. i.d.n.d.c.a.d.d.l.t.e.j.d.f.l.c.i.m.a.d.l.c.i.j.g.d.f.h.h.h.g.e.c.s.d.j.g.a.d.l.d.f.l.c.j.c.d.n.d.p.c.i.a.d.l.c.s.d.j.d.m.a.d.l.c.j.d.c.j.p.c.f.h.y.c.j.f.j.a.d.c.l.d.m.e.d.t.m.d.a.d.c.s.i.c.a.d.l.t.t.e.d.d.m.a.d.l.c.m.c.j.d.c.c.m.c.e.e.i.c.f.c.i.n.d.o.j.i.d.c.n.j.g.f.i.d.d.c.n.d.d.f.h.a.d.c.k.d.c.v.e.v.f.e.c.j.d.b.f.d.e.d.r.g.j.l.j.o.d.d.n.s.e.f.d.b.f.i.d.d.c.p.c.d.i.d.m.o.d.r.g.j.m.l.j.n.j.c.d.r.d.m.h.d.f.o.l.c.d.c.h.f.m.r.d.o.l.k.e.p.c.d.n.g.e.d.r.d.d.d.c.m.l.i.e.d.m.j.b.f.d.c.h.n.b.f.g.j.d.c.a.c.c.l.g.f.t.e.f.c.h.c.p.c.d.f.d.m.d.c.f.d.m.j.d.r.n.t.d.m.h.g.c.d.f.r.b.f.a.d.l.d.p.c.b.d.l.c.m.i.c.a.d.l.t.d.d.m.l.h.f.r.a.d.c.c.c.d.f.n.d.d.k.c.d.d.v.c.a.d.l.c.d.p.c.d.m.d.d.b.i.d.e.c.d.m.a.d.c.d.c.d.d.i.c.a.d.b.d.d.b.c.d.d.f.o.d.m.c.x.j.a.d.q.p.d.m.a.d.p.d.t.c.e.a.d.c.d.d.i.n.a.d.d.d.h.c.c.d.p.d.n.d.d.d.s.a.d.c.c.d.d.d.s.b.d.c.d.c.d.d.s.a.d.c.c.d.d
#
# [50 | 203.35] loss=3.96 avg=3.79
# Saving checkpoint/run1/model-50
# Saving checkpoint/run1/model-60
# ======== SAMPLE 1 ========
#  why this is my first time seeing you. my first time in person. do not worry. i have no idea about this and nothing to say about it.
# the best weekend ever!! i would be so happy that i have a chance at seeing you. that you did not have to wait for me to come down from the stage at a different house to make it to the grand finals.
# takes a moment to stop. i have this crazy idea that you are just the man who will be the first to be in your place. will you do your way?.
# you're not so special. now i am only gonna be a student.
# i feel such a thrill when i see this guy that really is cute on me. even though that's a long story but it feels so real to see him in such a gorgeous light.
# there's so much to talk about in this room. i feel like an idiot, but i just wanna ask you this. is this why your housemates are so popular with each other? why all the weird looks you got in class?.
# i want to leave you alone.
# i only really love you for how it feels when it is your final time in a class.i do not know much more about how you feel than i do, but i really am happy that you are here. i would be really, really happy not having to have the class of my life!.
# this was my second time seeing you so i guess i can say that I was a shock to see this type of sight. even though my roommate told me i could not see her again but she is so kind even though i was so scared.
# i see you with tears everywhere. i hope you can be my family friend
# this is the first time i see you. i hope all the best for my future.
# if anyone has any secrets, do not let them enter my secrets and i will leave you to rot and die if you choose to make them, but that is ok, i am just afraid that the girl you have asked if anything will affect the rest of your life.
# if you feel that some of the members of your school, this class, are to do well in a new field. do not let them go to school and do not let their exams get out of hand. it does not matter if you are successful or fail. if you fail in a new field, you are done.
# we are all here to give a lesson and help students. if not, give some words of encouragement.
# i hope that you can learn a thing or another because i would like to confess that i actually look forward to the day when you are able to get a chance to shine like i did. so tell me something!
# so, this is an old post and i need to confess to myself about being a virgin. so glad it is over!
# i am a freshman this semester, so i have to confess for myself how bad my classmate really was in class. i can do better, so no, no, no. i am still very pretty, however i am an undergraduate and i have no more class time due to the fact that i have a girlfriend and my class is still quite crowded. however i am happy because of the fact that we are only so close! i feel so happy, to be honest; i feel that since the class starts and you are so quiet, i am happy to have someone to cheer up to as they will never hear me out. also because of their love for my girlfriend, i can go for a walk and if there, my girl can go. this is also just a normal and normal thing for us. and we also all feel that if we can do it too, please do it too, i promise, i do not regret it
# i have been asking how much it costs to pay for lunch for freshmen, because we do not have any. can you imagine those people that just pay for lunch but have nothing for their lunch.
# i have been in an anime before and always wished that i would get anime. for sure, the anime of your choice would definitely go down as one of the best anime in the world. i can easily imagine that you will be so hard at work that you will not be able to work out any details yet. so how much money are you looking at? would you like to show the other half of your class that you are not the one in the middle? i think you will be one of the best anime makers, that you won't be able to fail at the very most, and to finally say that your class will be a best effort anime.
# if you get the wrong impression, or what your class is called, i am afraid that i will be able to find a better teacher. i will get fired in a few days and i feel so lonely inside. i even find myself getting lonely inside.
# i have been reading a lot lately. i know a ton of different girl and boy stuff in this
#
# Saving checkpoint/run1/model-70
# [75 | 303.58] loss=2.87 avg=3.48
# Saving checkpoint/run1/model-80
# ======== SAMPLE 1 ========
#  bit of time to study. my first time was in jc i was just really lonely and i tried to get to know people i did not like. and when i did see people in my house, i think about them every year and hope they were my new friends too, but i have always been waiting for an opportunity to go out and get a girlfriend or get a boyfriend i did not have. for those who like to think that it is easy to get dumped all through the day and you can just look at the dating website which you already know about as an exercise in finding an alittle partner you want. but to my classmates, it does not do any favours for this time of year. so anyway...and this is a confession! im so afraid to say, im going to get in trouble for this one day! just wanna say that i know what to do! thank you so much again and im so looking forward to new year 2016!!
# today my first time did not get the same amount of results. for a girl to not get into a relationship with her boyfriend. so i went over to the friend of her to see what she had in mind about getting married..then she said all of that, why did i wait so long?? now i just feel weird, do not want to bother in this sense ever but if you want to do such an thing, let me know what you think! - girl of the night - i couldnt do it but you can too! if you know how to do it do not worry guys! she said all that, why could i wait for months, months?! you have all the resources you need. now what are you guys gonna do so that you can get to know and date you guy from an earlier point onwards?!!
# in a year of feeling lost i was happy to finally meet someone who i like. i met a really nice girl and my first date came up a long time ago. we were dating a guy by the name of a guy. we thought of one another for a while but now that we have gotten through it we're almost ready to go out together with him. we started dating a few years ago and we still have a good year in jc but now that we have done the same, we need a boyfriend to go out with! do not be such a fool i know i have a lot to learn and this is not gonna be my second time, i have to go overseas. i want to wait till i meet the right man to get my first girlfriend together!! you guys have been so supportive
# if anything, this time we talked about our feelings and everything, in between our awkward moments of having a crush on another guy. i would say i am in a bad mood because i have not gotten what i was hoping to get, but the fact that i am not is probably a sign of my depression. but hey, i only have the one thing that i wanna know, do not get angry at me! do not get angry at me for not being happy with what you did. do not get upset because i did not get what i promised to not be happy with because you gave me what i wanted. but i just have to focus on my job, i can not concentrate on being happy, and i am not happy for anyone like me! what i do want is someone with me and would not do anything to get to know that person.-
# i have had the privilege of working in the area where the average male is only . i think there are a lot of guys who would call themselves nerds and not be as into anime as the females who are more into gaijin. but there are guys like yourself who would want their own unique style of life and have a passion for video games as well. my personal style is in terms of fighting games. while it is cute, in terms of gaming, it does not really interest me at all, even though my friends like it, they're just looking for it.-
# a super nice girl! i hope i can have more opportunities to meet you guys if that is alright with you guys, you have been so friendly with my girl since school! thanks for giving a nice smile again!.-
# i have been thinking about whether i should be a teacher in a non-singapore university because it was in a school run by the university in singapore, even though i did not have any interest in education. what if there's a university school that offers only a single class?, i really hope they get me to study as a lecturer in the second grade and so that i will not have to rely on being promoted to the first-grade lecturers. but if so, you guys, you guys, are really a wonderful group of people who really love us and will always take care of us so that we may be treated as a family someday! you're the group of professors and teachers who are really good that i really love and will always take care of me!! just please go to
#
# Saving checkpoint/run1/model-90
# [100 | 401.55] loss=3.86 avg=3.58
# Saving checkpoint/run1/model-100

# %%
# save checkpoint to google drive
gpt2.copy_checkpoint_to_gdrive(run_name='run1')

# %% [markdown]
# ## Test the fine-tuned GPT-2 model on the 3 test sentences

# %% [markdown]
# ## Text starter 1: here i am testing my nlg project…

# %%
# once the training is done, do the text generation
gpt2.generate(sess,
              length=30,  # number of tokens generated
              temperature=0.7, # randomness in the values
              prefix="here i am testing my nlg project", # the start of the sentence
              nsamples=3, # number of sample sentences produced
              batch_size=1, # get the batch size
              top_k=50, # number of tokens taken into account for the text generation
              run_name='run1')
# Out:
# here i am testing my nlg project. this is the first time i have tested an object from nlg. the results are encouraging. but i can not believe what i am doing
# ====================
# here i am testing my nlg project. i am in a ctu, and i am really into studying nlg. but it is still hard work to get a nlg
# ====================
# here i am testing my nlg project from this week and i am so happy to be back in nlg. i am so happy to be back in nlg and thank you
# ====================

# %% [markdown]
# ## Text starter 2: never did i have…

# %%
# once the training is done, do the text generation
gpt2.generate(sess,
              length=30,  # number of tokens generated
              temperature=0.7, # randomness in the values
              prefix="never did i have", # the start of the sentence
              nsamples=3, # number of sample sentences produced
              batch_size=1, # get the batch size
              top_k=50, # number of tokens taken into account for the text generation
              run_name='run1')
# Out:
# never did i have to talk to her. i was worried i would get mad at her and i am glad she is fine. i do not know who the girl is
# ====================
# never did i have time to think about it .i am sorry i thought of that but i just can not look at it. if i did, i would not have
# ====================
# never did i have to put in the effort to stay in the school.i really feel that i will never get to stay in a school that is so full of people
# ====================

# %% [markdown]
# ## Text starter 3: someday i will…

# %%
# once the training is done, do the text generation
gpt2.generate(sess,
              length=30,  # number of tokens generated
              temperature=0.7, # randomness in the values
              prefix="someday i will", # the start of the sentence
              nsamples=3, # number of sample sentences produced
              batch_size=1, # get the batch size
              top_k=50, # number of tokens taken into account for the text generation
              run_name='run1')
# Out:
# someday i will be leaving you and the rest of the world with my own little girl. but i need some help with my feelings for you. you seem to be
# ====================
# someday i will be back and i have been thinking of you for some time.
# is there any way to stop seeing you?.i am in a similar situation
# ====================
# someday i will be attending the first day of the new year celebrations at the local library to celebrate my new year. please feel free to come out to see me and
# ====================

# %% [markdown]
# ## Long text generation example

# %% [markdown]
# ## Text starter 4
# i'm very interested in the field of artificial intelligence, it gives me ample opportunities to explore what i want to know

# %%
# once the training is done, do the text generation
gpt2.generate(sess,
              length=100,  # number of tokens generated
              temperature=0.7, # randomness in the values
              prefix="""i'm very interested in the field of artificial intelligence, it gives me ample opportunities to explore what i want to know""", # the start of the sentence
              nsamples=3, # number of sample sentences produced
              batch_size=1, # get the batch size
              top_k=50, # number of tokens taken into account for the text generation
              run_name='run1')
# Out:
# i'm very interested in the field of artificial intelligence, it gives me ample opportunities to explore what i want to know and what i am not. i am also much more interested in what i am doing and what i am not doing.i have also found that i am not as motivated as i used to be. i have been doing it for years, but the pace of it has slowly changed. i am now on my own and i am being forced to do things that i am not prepared to do. i am not sure if i am really ready yet, but i am feeling a little guilty about it.
# ====================
# i'm very interested in the field of artificial intelligence, it gives me ample opportunities to explore what i want to know. i have no idea where i am going to go this year, but i am hoping to find someone who knows me.
# i have been doing this for a few years now, and i have never been afraid to post this at least twice. it is so good to be able to see my relatives for the first time, and i do not feel bad because i am very happy to have them around. but no matter how much i try, i can not get enough of them. i have
# ====================
# i'm very interested in the field of artificial intelligence, it gives me ample opportunities to explore what i want to know. i have been looking forward to this field since i was a kid and i have been thinking about it for years. but since i am not a high school student, i am just not too sure. so i am not going to be a part of a science-based engineering school. i am still not sure if i will be a part of any sciences. i am not sure if i should have chosen some of the sciences myself. i am not sure if i should have chosen the physics or
# ====================
